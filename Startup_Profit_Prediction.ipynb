# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Data Reading

# %%
data = pd.read_csv('/content/start_ups (1).csv')

# %%
data.head(5)
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94

# %% [markdown]
# # **Analysis**
#
# 1.   R&D Spend avg
# 2.   Adminstration avg
#
# 3.   Marketing avg
# 4.   Which state that has the highest R&D spend, Adminstration and Marketing spend?
#
#
# 5.   Which state that has the higgest profit?
# 6.   Which feature shows the stronger correlation with profit?

# %% [markdown]
# # R&D Spend avg = 74492.5

# %%
data['R&D Spend'].mean()
# Out:
# np.float64(74492.45615384617)

# %% [markdown]
# # Adminstration avg = 122287.2

# %%
data['Administration'].mean()
# Out:
# np.float64(122287.22923076923)

# %% [markdown]
# # Marketing avg  = 212526.4

# %%
data['Marketing Spend'].mean()
# Out:
# np.float64(212526.4175)

# %% [markdown]
# # Which state that has the highest R&D spend, Adminstration and Marketing spend?

# %%
# [state,  R&D spend] = New York
new_frame1 = data[['State', 'R&D Spend']]
new_frame1.groupby('State').mean()
# Out:
#                R&D Spend
# State
# California  62297.677778
# Florida     80724.016250
# New York    81148.070000

# %%
# [state , Adminstration ] = California
new_frame2 = data[['State', 'Administration']]
new_frame2.groupby('State').mean()
# Out:
#             Administration
# State
# California   122638.708889
# Florida      121768.897500
# New York     122396.488889

# %%
# [state , Marketing spend ] = Florida
new_frame3 = data[['State', 'Marketing Spend']]
new_frame3.groupby('State').mean()
# Out:
#             Marketing Spend
# State
# California    173973.917778
# Florida       247323.551250
# New York      220148.131667

# %% [markdown]
# # Which state that has the higgest profit?  Florida

# %%
new_frame4 = data[['State', 'Profit']]
new_frame4.groupby('State').mean()
# Out:
#                    Profit
# State
# California  101754.906111
# Florida     118774.024375
# New York    118117.856667

# %% [markdown]
# # Which feature shows the stronger correlation with profit?
#
# R&D Spend          0.975517
#
# "The more R&D Spend increases, the more profit ncreases"

# %%
df = data.select_dtypes(include= ['number'])

# %%
correlation = df.corr()
print(correlation ['Profit'].drop('Profit'))
# Out:
# R&D Spend          0.975517
# Administration     0.181586
# Marketing Spend    0.774315
# Name: Profit, dtype: float64

# %% [markdown]
# # Split the data in to features (x) and label (y)

# %%
x = data.iloc [:, 0:4]
y = data.iloc [:, 4:5]

# %% [markdown]
# # Missing values

# %%
data.isnull().sum()
# Out:
# R&D Spend          0
# Administration     0
# Marketing Spend    0
# State              0
# Profit             0
# dtype: int64

# %% [markdown]
# # Check if there are dupes or not

# %%
print(x.duplicated().any())
# Out:
# True

# %% [markdown]
# # Merge dupes

# %%
x = x.drop_duplicates()

# %%
y=y.drop_duplicates()

# %% [markdown]
# # Data categories

# %% [markdown]
# * Numerical = R&D Spend	, Administration	, Marketing Spend	& Profit.
#
# * Nominal = State

# %% [markdown]
# # Transforming the text data into Numbers

# %%
x= pd.get_dummies(x)

# %%
x
# Out:
#     R&D Spend  Administration  Marketing Spend  State_California  \
# 0   165349.20       136897.80        471784.10             False
# 1   162597.70       151377.59        443898.53              True
# 2   153441.51       101145.55        407934.54             False
# 3   144372.41       118671.85        383199.62             False
# 4   142107.34        91391.77        366168.42             False
# 5   131876.90        99814.71        362861.36             False
# 6   134615.46       147198.87        127716.82              True
# 7   130298.13       145530.06        323876.68             False
# 8   120542.52       148718.95        311613.29             False
# 9   123334.88       108679.17        304981.62              True
# 10  101913.08       110594.11        229160.95             False
# 11  100671.96        91790.61        249744.55              True
# 12   93863.75       127320.38        249839.44             False
# ...

# %% [markdown]
# # Scaling

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler_x = MinMaxScaler(feature_range=(0,1))
scaler_y = MinMaxScaler(feature_range=(0,1))

# %%
x = scaler_x.fit_transform(x)
y = scaler_y.fit_transform(y)

# %%
y
# Out:
# array([[1.        ],
#        [0.99735461],
#        [0.99317808],
#        [0.94729239],
#        [0.85317138],
#        [0.80138177],
#        [0.79649041],
#        [0.79440736],
#        [0.77446805],
#        [0.7606613 ],
#        [0.74017475],
#        [0.72968626],
#        [0.71462897],
#        [0.67364377],
#        [0.66404417],
#        [0.64892083],
#        [0.63245443],
#        [0.62331739],
#        [0.61710347],
#        [0.60871268],
#        [0.58448237],
#        [0.54415692],
#        [0.53874658],
#        [0.52963376],
#        [0.52860915],
#        [0.52214616],
#        [0.51273747],
#        [0.50865352],
#        [0.49893437],
#        [0.48610784],
#        [0.48009902],
#        [0.46627976],
#        [0.46596599],
#        [0.46231175],
#        [0.46193942],
#        [0.4606257 ],
#        [0.42812595],
#        [0.42385155],
#        [0.37474659],
#        [0.37348913],
#        [0.35791393],
#        [0.3554301 ],
#        [0.3199513 ],
# ...

# %% [markdown]
# # Split the data into train and test sets

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)

# %%
len(y_train)
# Out:
# 40

# %% [markdown]
# # AI

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
model.score(x_test, y_test)
# Out:
# 0.9189820443716128
